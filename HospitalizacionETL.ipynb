# %% [markdown]
# ## Proceso de ETL (Extracción, Transformación y Carga de datos)

# %% [markdown]
# En este notebook se realizará un proceso de carga de datos, revisaremos la consistencia de los mismos y los limpiaremos, para al final exportarlos ya listos para ser explorados

# %% [markdown]
# ### Importamos de librerías

# %%
#Las librerías se utilizan para hacer manejo de los datos
import pandas as pd
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Carga de datos

# %%
#Extraemos la información del archivo Excel que nos entregaron
dataframe = pd.read_excel('BBDD_Hospitalización.xlsx')
dataframe
# Out:
#      EDAD DIABETES HOSPITALIZACIÓN ULTIMO MES    PSA BIOPSIAS PREVIAS  \
# 0    53.0       NO                         NO   4.00               NO
# 1    56.0       NO                         NO   7.70               NO
# 2    57.0       NO                         NO  29.00               SI
# 3    56.0       NO                         NO   7.00               NO
# 4    55.0       NO                         NO  29.00               SI
# ..    ...      ...                        ...    ...              ...
# 565  69.0       NO                         NO   4.43              NaN
# 566  67.0       NO                         NO   8.00               NO
# 567  59.0       NO                         NO   9.00               SI
# 568   NaN      NaN                        NaN    NaN              NaN
# 569   NaN      NaN                        NaN    NaN              NaN
#
#     VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# 0                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 1                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 2                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 3                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 4                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# ..                 ...                                     ...
# 565                NaN          FLUOROQUINOLONA_AMINOGLICOSIDO
# 566                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 567                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 568                NaN                                     NaN
# 569                NaN                                     NaN
#
#      NUMERO DE MUESTRAS TOMADAS  CUP ENF. CRONICA PULMONAR OBSTRUCTIVA  \
# 0                          12.0   NO                                NO
# 1                          12.0   NO                                NO
# 2                          24.0   NO                                NO
# 3                          12.0   NO                                NO
# 4                          24.0   NO                                NO
# ..                          ...  ...                               ...
# 565                        20.0  NaN                                NO
# 566                        12.0   NO                               NaN
# 567                        12.0   NO                               NaN
# 568                         NaN  NaN                               NaN
# 569                         NaN  NaN                               NaN
#
#                        BIOPSIA  \
# 0                          NEG
# 1                          NEG
# 2                          NEG
# 3                          NEG
# 4                          NEG
# ..                         ...
# 565                        NEG
# 566  ADENOCARCINOMA GLEASON 7
# 567                        NEG
# 568                        NaN
# 569                        NaN
#
#     NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 565                                                 NO
# 566                                                 NO
# 567                                                 NO
# 568                                                NaN
# 569                                                NaN
#
#     FIEBRE  ITU TIPO DE CULTIVO AGENTE AISLADO  \
# 0       SI   NO              NO             NO
# 1       SI   NO              NO             NO
# 2       SI   NO     HEMOCULTIVO         E.COLI
# 3       SI   NO              NO             NO
# 4       SI   NO     HEMOCULTIVO         E.COLI
# ..     ...  ...             ...            ...
# 565     NO   NO              NO             NO
# 566     NO   NO              NO            NaN
# 567     NO   NO              NO             NO
# 568    NaN  NaN             NaN            NaN
# 569    NaN  NaN             NaN            NaN
#
#                     PATRON DE RESISTENCIA HOSPITALIZACION  \
# 0                                      NO              SI
# 1                                      NO              SI
# 2     AMPI R, CIPRO R, GENTA R, SULFA M R              SI
# 3                                      NO              SI
# 4                                      NO              SI
# ..                                    ...             ...
# 565                                    NO              NO
# 566                                    NO              NO
# 567                                    NO              NO
# 568                                   NaN             NaN
# 569                                   NaN             NaN
#
#      DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# 0                        2.0                       0.0
# 1                        5.0                       0.0
# 2                        4.0                       3.0
# 3                        5.0                       0.0
# 4                        4.0                       3.0
# ..                       ...                       ...
# 565                      0.0                       0.0
# 566                      0.0                       0.0
# 567                      0.0                       0.0
# 568                      NaN                       NaN
# 569                      NaN                       NaN
#
# [570 rows x 20 columns]

# %% [markdown]
# ### Transformación de datos

# %%
#Verificamos la existencia de duplicados en el data frame
duplicados = dataframe.duplicated()
duplicados.value_counts()
# Out:
# False    461
# True     109
# Name: count, dtype: int64

# %%
#Se creó un nuevo data frame sin los duplicados
data = dataframe.drop_duplicates(keep='first')
data
# Out:
#      EDAD DIABETES HOSPITALIZACIÓN ULTIMO MES    PSA BIOPSIAS PREVIAS  \
# 0    53.0       NO                         NO   4.00               NO
# 1    56.0       NO                         NO   7.70               NO
# 2    57.0       NO                         NO  29.00               SI
# 3    56.0       NO                         NO   7.00               NO
# 4    55.0       NO                         NO  29.00               SI
# ..    ...      ...                        ...    ...              ...
# 564  64.0       NO                         NO   4.80               NO
# 565  69.0       NO                         NO   4.43              NaN
# 566  67.0       NO                         NO   8.00               NO
# 567  59.0       NO                         NO   9.00               SI
# 568   NaN      NaN                        NaN    NaN              NaN
#
#     VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# 0                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 1                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 2                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 3                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 4                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# ..                 ...                                     ...
# 564                 SI                                   OTROS
# 565                NaN          FLUOROQUINOLONA_AMINOGLICOSIDO
# 566                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 567                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 568                NaN                                     NaN
#
#      NUMERO DE MUESTRAS TOMADAS  CUP ENF. CRONICA PULMONAR OBSTRUCTIVA  \
# 0                          12.0   NO                                NO
# 1                          12.0   NO                                NO
# 2                          24.0   NO                                NO
# 3                          12.0   NO                                NO
# 4                          24.0   NO                                NO
# ..                          ...  ...                               ...
# 564                        12.0   NO                                NO
# 565                        20.0  NaN                                NO
# 566                        12.0   NO                               NaN
# 567                        12.0   NO                               NaN
# 568                         NaN  NaN                               NaN
#
#                        BIOPSIA  \
# 0                          NEG
# 1                          NEG
# 2                          NEG
# 3                          NEG
# 4                          NEG
# ..                         ...
# 564  ADENOCARCINOMA GLEASON 7
# 565                        NEG
# 566  ADENOCARCINOMA GLEASON 7
# 567                        NEG
# 568                        NaN
#
#     NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 564                                                 NO
# 565                                                 NO
# 566                                                 NO
# 567                                                 NO
# 568                                                NaN
#
#     FIEBRE  ITU TIPO DE CULTIVO AGENTE AISLADO  \
# 0       SI   NO              NO             NO
# 1       SI   NO              NO             NO
# 2       SI   NO     HEMOCULTIVO         E.COLI
# 3       SI   NO              NO             NO
# 4       SI   NO     HEMOCULTIVO         E.COLI
# ..     ...  ...             ...            ...
# 564     NO   NO              NO             NO
# 565     NO   NO              NO             NO
# 566     NO   NO              NO            NaN
# 567     NO   NO              NO             NO
# 568    NaN  NaN             NaN            NaN
#
#                     PATRON DE RESISTENCIA HOSPITALIZACION  \
# 0                                      NO              SI
# 1                                      NO              SI
# 2     AMPI R, CIPRO R, GENTA R, SULFA M R              SI
# 3                                      NO              SI
# 4                                      NO              SI
# ..                                    ...             ...
# 564                                    NO              NO
# 565                                    NO              NO
# 566                                    NO              NO
# 567                                    NO              NO
# 568                                   NaN             NaN
#
#      DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# 0                        2.0                       0.0
# 1                        5.0                       0.0
# 2                        4.0                       3.0
# 3                        5.0                       0.0
# 4                        4.0                       3.0
# ..                       ...                       ...
# 564                      0.0                       0.0
# 565                      0.0                       0.0
# 566                      0.0                       0.0
# 567                      0.0                       0.0
# 568                      NaN                       NaN
#
# [461 rows x 20 columns]

# %%
#Se observa cuántas columnas tiene, cantidad de valores y tipo de dato
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 20 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   EDAD                                                                       568 non-null    float64
#  1   DIABETES                                                                   568 non-null    object
#  2   HOSPITALIZACIÓN ULTIMO MES                                                 568 non-null    object
#  3   PSA                                                                        564 non-null    float64
#  4   BIOPSIAS PREVIAS                                                           566 non-null    object
#  5   VOLUMEN PROSTATICO                                                         567 non-null    object
#  6   ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS                                    568 non-null    object
#  7   NUMERO DE MUESTRAS TOMADAS                                                 568 non-null    float64
#  8   CUP                                                                        567 non-null    object
#  9   ENF. CRONICA PULMONAR OBSTRUCTIVA                                          566 non-null    object
#  10  BIOPSIA                                                                    568 non-null    object
#  11  NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  568 non-null    object
#  12  FIEBRE                                                                     568 non-null    object
#  13  ITU                                                                        568 non-null    object
#  14  TIPO DE CULTIVO                                                            568 non-null    object
#  15  AGENTE AISLADO                                                             551 non-null    object
#  16  PATRON DE RESISTENCIA                                                      568 non-null    object
#  17  HOSPITALIZACION                                                            565 non-null    object
#  18  DIAS HOSPITALIZACION MQ                                                    568 non-null    float64
#  19  DIAS HOSPITALIZACIÓN UPC                                                   568 non-null    float64
# dtypes: float64(5), object(15)
# memory usage: 89.2+ KB

# %%
#Aquí se hizo un conteo de cuántas filas con valores tipo nulo tenemos y cuál es el porcentaje que representa
registros_Nan = len(data[data.isna().any(axis=1)])

totalnan = registros_Nan/len(data)

porcentajenan= round(totalnan*100,2)

print(f'Tenemos {registros_Nan} que es el {porcentajenan} % al representar poca cantidad los borramos')

data = data.dropna()
# Out:
# Tenemos 28 que es el 6.07 % al representar poca cantidad los borramos

# %%
#Se borró el índice anterior y se estableció uno nuevo ya que quitamos más de 120 filas
data.reset_index(inplace=True,drop=True)
data
# Out:
#      EDAD DIABETES HOSPITALIZACIÓN ULTIMO MES   PSA BIOPSIAS PREVIAS  \
# 0    53.0       NO                         NO   4.0               NO
# 1    56.0       NO                         NO   7.7               NO
# 2    57.0       NO                         NO  29.0               SI
# 3    56.0       NO                         NO   7.0               NO
# 4    55.0       NO                         NO  29.0               SI
# ..    ...      ...                        ...   ...              ...
# 428  55.0       NO                         NO   5.0               NO
# 429  70.0       SI                         NO  18.0               NO
# 430  75.0       NO                         NO  75.0               NO
# 431  67.0       NO                         NO   6.0               NO
# 432  64.0       NO                         NO   4.8               NO
#
#     VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# 0                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 1                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 2                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 3                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 4                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# ..                 ...                                     ...
# 428                 NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 429                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 430                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 431                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 432                 SI                                   OTROS
#
#      NUMERO DE MUESTRAS TOMADAS CUP ENF. CRONICA PULMONAR OBSTRUCTIVA  \
# 0                          12.0  NO                                NO
# 1                          12.0  NO                                NO
# 2                          24.0  NO                                NO
# 3                          12.0  NO                                NO
# 4                          24.0  NO                                NO
# ..                          ...  ..                               ...
# 428                        12.0  NO                                NO
# 429                        12.0  NO                                NO
# 430                        12.0  NO                                NO
# 431                        12.0  NO                                NO
# 432                        12.0  NO                                NO
#
#                        BIOPSIA  \
# 0                          NEG
# 1                          NEG
# 2                          NEG
# 3                          NEG
# 4                          NEG
# ..                         ...
# 428  ADENOCARCINOMA GLEASON 7
# 429                        NEG
# 430  ADENOCARCINOMA GLEASON 8
# 431   ADENOCARCINOMA GLEASON 6
# 432  ADENOCARCINOMA GLEASON 7
#
#     NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 428                                                 NO
# 429                                                 NO
# 430                                                 NO
# 431                                                 NO
# 432                                                 NO
#
#     FIEBRE ITU TIPO DE CULTIVO AGENTE AISLADO  \
# 0       SI  NO              NO             NO
# 1       SI  NO              NO             NO
# 2       SI  NO     HEMOCULTIVO         E.COLI
# 3       SI  NO              NO             NO
# 4       SI  NO     HEMOCULTIVO         E.COLI
# ..     ...  ..             ...            ...
# 428     NO  NO              NO             NO
# 429     NO  NO              NO             NO
# 430     NO  NO              NO             NO
# 431     NO  NO              NO             NO
# 432     NO  NO              NO             NO
#
#                     PATRON DE RESISTENCIA HOSPITALIZACION  \
# 0                                      NO              SI
# 1                                      NO              SI
# 2     AMPI R, CIPRO R, GENTA R, SULFA M R              SI
# 3                                      NO              SI
# 4                                      NO              SI
# ..                                    ...             ...
# 428                                    NO              NO
# 429                                    NO              NO
# 430                                    NO              NO
# 431                                    NO              NO
# 432                                    NO              NO
#
#      DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# 0                        2.0                       0.0
# 1                        5.0                       0.0
# 2                        4.0                       3.0
# 3                        5.0                       0.0
# 4                        4.0                       3.0
# ..                       ...                       ...
# 428                      0.0                       0.0
# 429                      0.0                       0.0
# 430                      0.0                       0.0
# 431                      0.0                       0.0
# 432                      0.0                       0.0
#
# [433 rows x 20 columns]

# %%
#Previamente observamos que la columna 11, que es de tipo entero, figura como object, así que la analizaremos
data['NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA'].value_counts()
# Out:
# NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA
# NO    408
# 2       8
# 3       8
# 1       5
# 5       2
# 9       2
# Name: count, dtype: int64

# %%
#Teníamos valores de tipo string junto con valores de tipo entero, la decisión fue pasar los valores 'NO' a un número 0
data['NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA']= data['NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA'].replace('NO',0)

# %%
#Corroboramos que se cambie "NO" por 0
data['NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA'].value_counts()
# Out:
# NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA
# 0    408
# 2      8
# 3      8
# 1      5
# 5      2
# 9      2
# Name: count, dtype: int64

# %%
#Tenemos variables numéricas que deberían ser enteras como decimales, debemos cambiar los tipos de datos
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 20 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   EDAD                                                                       433 non-null    float64
#  1   DIABETES                                                                   433 non-null    object
#  2   HOSPITALIZACIÓN ULTIMO MES                                                 433 non-null    object
#  3   PSA                                                                        433 non-null    float64
#  4   BIOPSIAS PREVIAS                                                           433 non-null    object
#  5   VOLUMEN PROSTATICO                                                         433 non-null    object
#  6   ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS                                    433 non-null    object
#  7   NUMERO DE MUESTRAS TOMADAS                                                 433 non-null    float64
#  8   CUP                                                                        433 non-null    object
#  9   ENF. CRONICA PULMONAR OBSTRUCTIVA                                          433 non-null    object
#  10  BIOPSIA                                                                    433 non-null    object
#  11  NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  433 non-null    int64
#  12  FIEBRE                                                                     433 non-null    object
#  13  ITU                                                                        433 non-null    object
#  14  TIPO DE CULTIVO                                                            433 non-null    object
#  15  AGENTE AISLADO                                                             433 non-null    object
#  16  PATRON DE RESISTENCIA                                                      433 non-null    object
#  17  HOSPITALIZACION                                                            433 non-null    object
#  18  DIAS HOSPITALIZACION MQ                                                    433 non-null    float64
#  19  DIAS HOSPITALIZACIÓN UPC                                                   433 non-null    float64
# dtypes: float64(5), int64(1), object(14)
# memory usage: 67.8+ KB

# %%
data['EDAD'] = data['EDAD'].astype(int)
data['NUMERO DE MUESTRAS TOMADAS'] = data['NUMERO DE MUESTRAS TOMADAS'].astype(int)
data['DIAS HOSPITALIZACION MQ'] = data['DIAS HOSPITALIZACION MQ'].astype(int)
data['DIAS HOSPITALIZACIÓN UPC'] = data['DIAS HOSPITALIZACIÓN UPC'].astype(int)

# %%
# En los próximos notebooks veremos que se verifican los conteos de las variables categóricas, para revisar si se está sumando los valores de forma correcta
data['AGENTE AISLADO'].value_counts()
# Out:
# AGENTE AISLADO
# NO                        425
# E.COLI                      6
# PSEUDOMONAS AERUGINOSA      2
# Name: count, dtype: int64

# %%
data['ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS'].value_counts()
# Out:
# ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS
# FLUOROQUINOLONA_AMINOGLICOSIDO    343
# CEFALOSPORINA_AMINOGLUCOCIDO       44
# OTROS                              33
# OROQUINOLONAS                      11
# FLUOROQUINOLONA_AMINOGLICÓSIDO      2
# Name: count, dtype: int64

# %%
#Aquí se encontró que tenemos dos antibióticos iguales pero uno posee acento y el otro no, procedemos a quitar el acento
data['ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS'] = data['ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS'].str.replace('Ó','O')

# %%
data['ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS'].value_counts()
# Out:
# ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS
# FLUOROQUINOLONA_AMINOGLICOSIDO    345
# CEFALOSPORINA_AMINOGLUCOCIDO       44
# OTROS                              33
# OROQUINOLONAS                      11
# Name: count, dtype: int64

# %%
data['BIOPSIA'].value_counts()
# Out:
# BIOPSIA
# NEG                                           213
# ADENOCARCINOMA GLEASON 7                       93
# ADENOCARCINOMA GLEASON 6                       37
# ADENOCARCINOMA GLEASON 9                       20
# ADENOCARCINOMA GLEASON 8                       19
# ADENOCARCINOMA GLEASON 6                       16
# HIPERPLASIA PROSTATICA                         12
# PROSTATITIS                                     9
# ADENOCARCINOMA GLEASON 7                        8
# ADENOCARCINOMA GLEASON 10                       4
# CARCINOMA INDIFERENCIADO DE CELULAS CLARAS      2
# Name: count, dtype: int64

# %%
# De esta forma revisamos los valores únicos, vemos por qué ADENOCARCINOMA GLEASON 6 Y 7 aparece dos veces, solo porque algunos poseen un espacio en blanco y otros no
data['BIOPSIA'].unique()
# Out:
# array(['NEG', 'ADENOCARCINOMA GLEASON 6 ', 'ADENOCARCINOMA GLEASON 7 ',
#        'ADENOCARCINOMA GLEASON 6', 'ADENOCARCINOMA GLEASON 10 ',
#        'ADENOCARCINOMA GLEASON 9 ', 'ADENOCARCINOMA GLEASON 8 ',
#        'PROSTATITIS', 'ADENOCARCINOMA GLEASON 7',
#        'HIPERPLASIA PROSTATICA',
#        'CARCINOMA INDIFERENCIADO DE CELULAS CLARAS'], dtype=object)

# %%
#Aquí lo que hacemos es eliminar los espacios en blanco que se encuentran a la derecha de los valores en la columna Biopsia
data['BIOPSIA'] = data['BIOPSIA'].str.rstrip()

# %%
data['BIOPSIA'].value_counts()
# Out:
# BIOPSIA
# NEG                                           213
# ADENOCARCINOMA GLEASON 7                      101
# ADENOCARCINOMA GLEASON 6                       53
# ADENOCARCINOMA GLEASON 9                       20
# ADENOCARCINOMA GLEASON 8                       19
# HIPERPLASIA PROSTATICA                         12
# PROSTATITIS                                     9
# ADENOCARCINOMA GLEASON 10                       4
# CARCINOMA INDIFERENCIADO DE CELULAS CLARAS      2
# Name: count, dtype: int64

# %%
data['TIPO DE CULTIVO'].value_counts()
# Out:
# TIPO DE CULTIVO
# NO                          425
# UROCULTIVO                    4
# HEMOCULTIVO                   2
# HEMOCULTIVO Y UROCULTIVO      2
# Name: count, dtype: int64

# %%
data['AGENTE AISLADO'].value_counts()
# Out:
# AGENTE AISLADO
# NO                        425
# E.COLI                      6
# PSEUDOMONAS AERUGINOSA      2
# Name: count, dtype: int64

# %%
data['PATRON DE RESISTENCIA'].value_counts()
# Out:
# PATRON DE RESISTENCIA
# NO                                                                                 426
# RESISTENTE A AMPI, CIPRO Y GENTA                                                     2
# RESISTENTE A AMPI, SULFA, CEFADROXILO, CEFUROXIMO, CIPRO Y CEFEPIME, CEFOTAXIMA      2
# MULTI SENSIBLE                                                                       2
#  AMPI R, CIPRO R, GENTA R, SULFA M R                                                 1
# Name: count, dtype: int64

# %%
data['PATRON DE RESISTENCIA'] = data['PATRON DE RESISTENCIA'].replace(' AMPI R, CIPRO R, GENTA R, SULFA M R', 'R AMPI, R GENTA, R SULFA')
data['PATRON DE RESISTENCIA'] = data['PATRON DE RESISTENCIA'].replace('RESISTENTE A AMPI, CIPRO Y GENTA', 'R AMPI, R CIPRO, R GENTA')
data['PATRON DE RESISTENCIA'] = data['PATRON DE RESISTENCIA'].replace('RESISTENTE A AMPI, SULFA, CEFADROXILO, CEFUROXIMO, CIPRO Y CEFEPIME, CEFOTAXIMA','R AMPI, R SULFA, R CEFADROXILO, R CEFUROXIMO, R CIPRO, R CEFEPIME')

# %%
data['ENF. CRONICA PULMONAR OBSTRUCTIVA'].value_counts()
# Out:
# ENF. CRONICA PULMONAR OBSTRUCTIVA
# NO          419
# SI            9
# SI, EPOC      3
# SI, ASMA      2
# Name: count, dtype: int64

# %%
data['ENF. CRONICA PULMONAR OBSTRUCTIVA'] = data['ENF. CRONICA PULMONAR OBSTRUCTIVA'].replace('SI, EPOC', 'SI')
data['ENF. CRONICA PULMONAR OBSTRUCTIVA'] = data['ENF. CRONICA PULMONAR OBSTRUCTIVA'].replace('SI, ASMA', 'SI')

# %%
data
# Out:
#      EDAD DIABETES HOSPITALIZACIÓN ULTIMO MES   PSA BIOPSIAS PREVIAS  \
# 0      53       NO                         NO   4.0               NO
# 1      56       NO                         NO   7.7               NO
# 2      57       NO                         NO  29.0               SI
# 3      56       NO                         NO   7.0               NO
# 4      55       NO                         NO  29.0               SI
# ..    ...      ...                        ...   ...              ...
# 428    55       NO                         NO   5.0               NO
# 429    70       SI                         NO  18.0               NO
# 430    75       NO                         NO  75.0               NO
# 431    67       NO                         NO   6.0               NO
# 432    64       NO                         NO   4.8               NO
#
#     VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# 0                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 1                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 2                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 3                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 4                   SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# ..                 ...                                     ...
# 428                 NO          FLUOROQUINOLONA_AMINOGLICOSIDO
# 429                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 430                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 431                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 432                 SI                                   OTROS
#
#      NUMERO DE MUESTRAS TOMADAS CUP ENF. CRONICA PULMONAR OBSTRUCTIVA  \
# 0                            12  NO                                NO
# 1                            12  NO                                NO
# 2                            24  NO                                NO
# 3                            12  NO                                NO
# 4                            24  NO                                NO
# ..                          ...  ..                               ...
# 428                          12  NO                                NO
# 429                          12  NO                                NO
# 430                          12  NO                                NO
# 431                          12  NO                                NO
# 432                          12  NO                                NO
#
#                       BIOPSIA  \
# 0                         NEG
# 1                         NEG
# 2                         NEG
# 3                         NEG
# 4                         NEG
# ..                        ...
# 428  ADENOCARCINOMA GLEASON 7
# 429                       NEG
# 430  ADENOCARCINOMA GLEASON 8
# 431  ADENOCARCINOMA GLEASON 6
# 432  ADENOCARCINOMA GLEASON 7
#
#      NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 428                                                  0
# 429                                                  0
# 430                                                  0
# 431                                                  0
# 432                                                  0
#
#     FIEBRE ITU TIPO DE CULTIVO AGENTE AISLADO     PATRON DE RESISTENCIA  \
# 0       SI  NO              NO             NO                        NO
# 1       SI  NO              NO             NO                        NO
# 2       SI  NO     HEMOCULTIVO         E.COLI  R AMPI, R GENTA, R SULFA
# 3       SI  NO              NO             NO                        NO
# 4       SI  NO     HEMOCULTIVO         E.COLI                        NO
# ..     ...  ..             ...            ...                       ...
# 428     NO  NO              NO             NO                        NO
# 429     NO  NO              NO             NO                        NO
# 430     NO  NO              NO             NO                        NO
# 431     NO  NO              NO             NO                        NO
# 432     NO  NO              NO             NO                        NO
#
#     HOSPITALIZACION  DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# 0                SI                        2                         0
# 1                SI                        5                         0
# 2                SI                        4                         3
# 3                SI                        5                         0
# 4                SI                        4                         3
# ..              ...                      ...                       ...
# 428              NO                        0                         0
# 429              NO                        0                         0
# 430              NO                        0                         0
# 431              NO                        0                         0
# 432              NO                        0                         0
#
# [433 rows x 20 columns]

# %%
#Cambiamos los nombres de la columna, son muy extensos e incómodos para trabajarlos, además le quita legibilidad
nombres = {
    "EDAD": "Edad",
    "DIABETES": "Diabetes",
    "HOSPITALIZACIÓN ULTIMO MES": "Hospitaliz_ultimo_mes",
    "PSA": "Psa",
    "BIOPSIAS PREVIAS": "Biopsias_prev",
    "VOLUMEN PROSTATICO": "Vol_prostatico",
    "ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS": "Antibiotico_profilaxis",
    "NUMERO DE MUESTRAS TOMADAS": "Nro_muestras",
    "CUP": "Cup",
    "ENF. CRONICA PULMONAR OBSTRUCTIVA": "Epoc",
    "BIOPSIA": "Biopsia",
    "NUMERO DE DIAS POST BIOPSIA EN QUE SE PRESENTA LA COMPLICACIÓN INFECCIOSA": "nro_dias_con_infecc",
    "FIEBRE": "Fiebre",
    "ITU": "Itu",
    "TIPO DE CULTIVO": "Tipo_cultivo",
    "AGENTE AISLADO": "Agente_aislado",
    "PATRON DE RESISTENCIA": "Patron_resistencia",
    "HOSPITALIZACION": "Hospitalizacion",
    "DIAS HOSPITALIZACION MQ": "Dias_hosp_mq",
    "DIAS HOSPITALIZACIÓN UPC": "Dias_hosp_upc" }

data.rename(columns=nombres, inplace=True)
data
# Out:
#      Edad Diabetes Hospitaliz_ultimo_mes   Psa Biopsias_prev Vol_prostatico  \
# 0      53       NO                    NO   4.0            NO             SI
# 1      56       NO                    NO   7.7            NO             SI
# 2      57       NO                    NO  29.0            SI             SI
# 3      56       NO                    NO   7.0            NO             SI
# 4      55       NO                    NO  29.0            SI             SI
# ..    ...      ...                   ...   ...           ...            ...
# 428    55       NO                    NO   5.0            NO             NO
# 429    70       SI                    NO  18.0            NO             SI
# 430    75       NO                    NO  75.0            NO             SI
# 431    67       NO                    NO   6.0            NO             SI
# 432    64       NO                    NO   4.8            NO             SI
#
#              Antibiotico_profilaxis  Nro_muestras Cup Epoc  \
# 0    FLUOROQUINOLONA_AMINOGLICOSIDO            12  NO   NO
# 1    FLUOROQUINOLONA_AMINOGLICOSIDO            12  NO   NO
# 2    FLUOROQUINOLONA_AMINOGLICOSIDO            24  NO   NO
# 3    FLUOROQUINOLONA_AMINOGLICOSIDO            12  NO   NO
# 4    FLUOROQUINOLONA_AMINOGLICOSIDO            24  NO   NO
# ..                              ...           ...  ..  ...
# 428  FLUOROQUINOLONA_AMINOGLICOSIDO            12  NO   NO
# 429  FLUOROQUINOLONA_AMINOGLICOSIDO            12  NO   NO
# 430  FLUOROQUINOLONA_AMINOGLICOSIDO            12  NO   NO
# 431  FLUOROQUINOLONA_AMINOGLICOSIDO            12  NO   NO
# 432                           OTROS            12  NO   NO
#
#                       Biopsia  nro_dias_con_infecc Fiebre Itu Tipo_cultivo  \
# 0                         NEG                    1     SI  NO           NO
# 1                         NEG                    1     SI  NO           NO
# 2                         NEG                    1     SI  NO  HEMOCULTIVO
# 3                         NEG                    1     SI  NO           NO
# 4                         NEG                    1     SI  NO  HEMOCULTIVO
# ..                        ...                  ...    ...  ..          ...
# 428  ADENOCARCINOMA GLEASON 7                    0     NO  NO           NO
# 429                       NEG                    0     NO  NO           NO
# 430  ADENOCARCINOMA GLEASON 8                    0     NO  NO           NO
# 431  ADENOCARCINOMA GLEASON 6                    0     NO  NO           NO
# 432  ADENOCARCINOMA GLEASON 7                    0     NO  NO           NO
#
#     Agente_aislado        Patron_resistencia Hospitalizacion  Dias_hosp_mq  \
# 0               NO                        NO              SI             2
# 1               NO                        NO              SI             5
# 2           E.COLI  R AMPI, R GENTA, R SULFA              SI             4
# 3               NO                        NO              SI             5
# 4           E.COLI                        NO              SI             4
# ..             ...                       ...             ...           ...
# 428             NO                        NO              NO             0
# 429             NO                        NO              NO             0
# 430             NO                        NO              NO             0
# 431             NO                        NO              NO             0
# 432             NO                        NO              NO             0
#
#      Dias_hosp_upc
# 0                0
# 1                0
# 2                3
# 3                0
# 4                3
# ..             ...
# 428              0
# 429              0
# 430              0
# 431              0
# 432              0
#
# [433 rows x 20 columns]

# %% [markdown]
# ### Exportación de datos

# %%
#Con el archivo ya limpio y transformado, lo exportamos en formato csv
data.to_csv('BBDD_hospitalizacion_limpio.csv', index=False, encoding='utf-8')

# %% [markdown]
# Desde [aquí](HospitalizacionEDA.ipynb) puede seguir hacia la siguiente etapa(EDA) 😃
